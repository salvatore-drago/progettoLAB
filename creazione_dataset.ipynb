# %%
from pyod.utils.data import generate_data_clusters

X_train, X_test, y_train, y_test=generate_data_clusters(n_train=200, n_test=50, n_clusters=3, n_features=2, contamination=0.1, size='different', density='different', dist=0.99, random_state=1)
print(X_train)
# Out:
# [[  108.24150618  -249.51000369]
#  [  587.15014504   591.87401388]
#  [-1632.63247289 -1359.48077649]
#  [ -562.89680512  -565.76587021]
#  [ -562.46600422  -565.91889196]
#  [  587.10085221   591.66154964]
#  [ -562.80294715  -565.92743534]
#  [  587.23202244   592.16805511]
#  [  107.99465841  -249.48808155]
#  [ -562.48437412  -565.44599598]
#  [  586.86298996   591.90241456]
#  [  587.08343668   592.00080781]
#  [ -562.90921724  -566.2619161 ]
#  [ -562.82631138  -565.58669182]
#  [-1638.98535052 -1355.00516661]
#  [  108.30796491  -249.4026865 ]
#  [  108.33832392  -249.52587531]
#  [ -562.80007042  -565.47807484]
#  [  586.56986413   591.72379328]
#  [ -562.23922748  -565.89083628]
#  [  153.54296299  -751.92773895]
#  [  108.20524359  -249.34745705]
#  [  587.18692275   592.01088292]
#  [  587.15433616   591.866132  ]
#  [  587.24395325   591.83441327]
#  [  586.8995321    592.17597312]
#  [  108.07801965  -249.7865387 ]
#  [ -563.45835617  -565.69991545]
# ...
